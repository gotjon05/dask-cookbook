# %%
import dask.dataframe as dd

# %%
df = dd.read_csv('../Gladys/Downloads/311_Service_Requests_from_2010_to_Present.csv', dtype = 'str')

# %%
df.head()
# Out:
#   Unique Key            Created Date             Closed Date Agency  \
# 0   25227343  03/21/2013 12:00:00 AM  04/03/2013 12:00:00 AM    HPD
# 1   25227344  03/21/2013 07:00:00 PM  03/22/2013 09:43:00 AM    DOT
# 2   25227345  03/21/2013 07:42:00 PM  03/22/2013 02:26:00 PM    DOT
# 3   25227346  03/21/2013 12:00:00 AM  04/04/2013 12:00:00 AM    HPD
# 4   25227347  03/21/2013 12:00:00 AM  03/25/2013 12:00:00 AM    HPD
#
#                                          Agency Name          Complaint Type  \
# 0  Department of Housing Preservation and Develop...    GENERAL CONSTRUCTION
# 1                       Department of Transportation  Street Light Condition
# 2                       Department of Transportation  Street Light Condition
# 3  Department of Housing Preservation and Develop...    GENERAL CONSTRUCTION
# 4  Department of Housing Preservation and Develop...    GENERAL CONSTRUCTION
#
#          Descriptor         Location Type Incident Zip       Incident Address  \
# ...

# %%
df = df.rename(columns={c: c.replace(' ', '') for c in df.columns})

# %%
df.head()
# Out:
#   UniqueKey             CreatedDate              ClosedDate Agency  \
# 0  25227343  03/21/2013 12:00:00 AM  04/03/2013 12:00:00 AM    HPD
# 1  25227344  03/21/2013 07:00:00 PM  03/22/2013 09:43:00 AM    DOT
# 2  25227345  03/21/2013 07:42:00 PM  03/22/2013 02:26:00 PM    DOT
# 3  25227346  03/21/2013 12:00:00 AM  04/04/2013 12:00:00 AM    HPD
# 4  25227347  03/21/2013 12:00:00 AM  03/25/2013 12:00:00 AM    HPD
#
#                                           AgencyName           ComplaintType  \
# 0  Department of Housing Preservation and Develop...    GENERAL CONSTRUCTION
# 1                       Department of Transportation  Street Light Condition
# 2                       Department of Transportation  Street Light Condition
# 3  Department of Housing Preservation and Develop...    GENERAL CONSTRUCTION
# 4  Department of Housing Preservation and Develop...    GENERAL CONSTRUCTION
#
#          Descriptor          LocationType IncidentZip        IncidentAddress  \
# ...

# %%
myzip = df[df['IncidentZip'] == '10034']

# %%
myzip[:3]
# Out:
# Dask DataFrame Structure:
#                 UniqueKey CreatedDate ClosedDate  Agency AgencyName ComplaintType Descriptor LocationType IncidentZip IncidentAddress StreetName CrossStreet1 CrossStreet2 IntersectionStreet1 IntersectionStreet2 AddressType    City Landmark FacilityType  Status DueDate ResolutionDescription ResolutionActionUpdatedDate CommunityBoard     BBL Borough XCoordinate(StatePlane) YCoordinate(StatePlane) OpenDataChannelType ParkFacilityName ParkBorough VehicleType TaxiCompanyBorough TaxiPickUpLocation BridgeHighwayName BridgeHighwayDirection RoadRamp BridgeHighwaySegment Latitude Longitude Location
# npartitions=160
# ...

# %%
myzip[:3].compute()
# Out:
# Empty DataFrame
# Columns: [UniqueKey, CreatedDate, ClosedDate, Agency, AgencyName, ComplaintType, Descriptor, LocationType, IncidentZip, IncidentAddress, StreetName, CrossStreet1, CrossStreet2, IntersectionStreet1, IntersectionStreet2, AddressType, City, Landmark, FacilityType, Status, DueDate, ResolutionDescription, ResolutionActionUpdatedDate, CommunityBoard, BBL, Borough, XCoordinate(StatePlane), YCoordinate(StatePlane), OpenDataChannelType, ParkFacilityName, ParkBorough, VehicleType, TaxiCompanyBorough, TaxiPickUpLocation, BridgeHighwayName, BridgeHighwayDirection, RoadRamp, BridgeHighwaySegment, Latitude, Longitude, Location]
# Index: []
#
# [0 rows x 41 columns]

# %%
myzip.compute()
# Out:
#       UniqueKey             CreatedDate              ClosedDate Agency  \
# 248    25227623  03/22/2013 12:00:00 AM                     NaN  DOHMH
# 255    25227643  03/22/2013 02:01:10 PM  03/25/2013 09:50:42 AM    DOF
# 427    25227992  03/22/2013 12:00:00 AM  03/28/2013 12:00:00 AM    HPD
# 428    25227993  03/22/2013 12:00:00 AM  04/05/2013 12:00:00 AM    HPD
# 501    25228056  03/22/2013 03:18:00 PM  05/21/2013 12:15:00 AM    DOT
# 576    25228131  03/22/2013 03:20:00 PM  03/21/2013 12:30:00 AM    DOT
# 584    25228147  03/22/2013 12:00:00 AM  04/05/2013 12:00:00 AM    HPD
# 811    25228423  03/22/2013 12:00:00 AM  03/23/2013 12:00:00 AM    HPD
# 958    25228689  03/21/2013 04:53:55 PM  03/28/2013 12:00:00 AM    DOB
# 1032   25228858  03/22/2013 03:08:38 PM  03/29/2013 04:20:36 PM    DOF
# 1045   25228871  03/22/2013 12:00:00 AM  04/15/2013 12:00:00 AM    HPD
# 1087   25228915  03/22/2013 12:00:00 AM  04/15/2013 12:00:00 AM    HPD
# ...

# %%
myzip = df[df.'IncidentZip' == '10034']
# Out:
#   File "<ipython-input-10-407423631f8c>", line 1
#     myzip = df[df.'IncidentZip' == '10034']
#                               ^
# SyntaxError: invalid syntax

# %%
party_noise = df[df['Descriptor'] == "Loud Music/Party"]

# %%
party_noise['Borough'].value_counts()
# Out:
# Dask Series Structure:
# npartitions=1
#     int64
#       ...
# Name: Borough, dtype: int64
# Dask Name: value-counts-agg, 1464 tasks

# %%
party_noise['Borough'].value_counts().compute()
# Out:
# BROOKLYN         421823
# MANHATTAN        393654
# BRONX            289519
# QUEENS           248491
# STATEN ISLAND     35511
# Unspecified        4154
# Name: Borough, dtype: int64

# %%
party_noise_count = party_noise['Borough'].value_counts()

# %%
party_noise_count.plot()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-15-70ed720e19a2> in <module>()
# ----> 1 party_noise_count.plot()
#
# AttributeError: 'Series' object has no attribute 'plot'

# %%
party_noise_count.compute().plot()

# %%
party_noise_count.compute().plot().compute()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-17-2d726e4b162f> in <module>()
# ----> 1 party_noise_count.compute().plot().compute()
#
# AttributeError: 'AxesSubplot' object has no attribute 'compute'

# %%
party_noise_count.plot(kind='bar').compute()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-18-4fe4f79c59e0> in <module>()
# ----> 1 party_noise_count.plot(kind='bar').compute()
#
# AttributeError: 'Series' object has no attribute 'plot'

# %%
party_noise_count.compute().plot(kind='bar').compute()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-19-13096f5e94dd> in <module>()
# ----> 1 party_noise_count.compute().plot(kind='bar').compute()
#
# AttributeError: 'AxesSubplot' object has no attribute 'compute'

# %%
party_noise_count.compute().plot(kind='bar')
